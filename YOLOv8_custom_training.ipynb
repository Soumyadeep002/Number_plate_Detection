# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.yaml')
# model.to('cuda')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# model.predict(source="data/Datacluster_number_plates (95).jpg")

# %%
model.train(data="data.yaml", epochs=50)
# Out:
# Ultralytics YOLOv8.0.190  Python-3.10.10 torch-2.0.1+cpu CPU (12th Gen Intel Core(TM) i5-12600K)
# ...

# %%
my_model = YOLO('E:\\My Projects\\Number Plate detection\\1st Try\\weights\\best.pt')

# %%
result = my_model.predict('E:\\My Projects\\Number Plate detection\\alll\\images\\00000044.jpg')
# Out:
# image 1/1 E:\My Projects\Number Plate detection\alll\images\00000044.jpg: 640x384 1 Front Plate, 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)

# %%
type(result)
# Out:
# list

# %%
result
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Front Plate', 1: 'Back Plate'}
#  orig_img: array([[[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [16, 45, 52],
#          [20, 45, 55],
#          [26, 46, 57]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [16, 45, 52],
#          [20, 45, 55],
#          [26, 46, 57]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [16, 45, 52],
#          [20, 45, 55],
#          [25, 45, 56]],
#
#         ...,
#
#         [[25, 25, 25],
#          [25, 25, 25],
#          [26, 26, 26],
#          ...,
#          [34, 27, 24],
#          [34, 27, 24],
#          [34, 27, 24]],
#
#         [[24, 24, 24],
#          [25, 25, 25],
#          [26, 26, 26],
#          ...,
# ...
