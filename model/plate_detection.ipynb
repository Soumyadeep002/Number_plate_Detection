# %%
import numpy as np
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\My Projects\Number Plate detection\plate_detection.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/e%3A/My%20Projects/Number%20Plate%20detection/plate_detection.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/e%3A/My%20Projects/Number%20Plate%20detection/plate_detection.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from ultralytics import YOLO
#       <a href='vscode-notebook-cell:/e%3A/My%20Projects/Number%20Plate%20detection/plate_detection.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import cv2
#       <a href='vscode-notebook-cell:/e%3A/My%20Projects/Number%20Plate%20detection/plate_detection.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import matplotlib.pyplot as plt
#
# File e:\My Projects\Number Plate detection\myvenv\lib\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 __version__ = '8.0.190'
# ----> 5 from ultralytics.models import RTDETR, SAM, YOLO
#       6 from ultralytics.models.fastsam import FastSAM
#       7 from ultralytics.models.nas import NAS
#
# File e:\My Projects\Number Plate detection\myvenv\lib\site-packages\ultralytics\models\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .rtdetr import RTDETR
#       4 from .sam import SAM
#       5 from .yolo import YOLO
#
# File e:\My Projects\Number Plate detection\myvenv\lib\site-packages\ultralytics\models\rtdetr\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .model import RTDETR
#       4 from .predict import RTDETRPredictor
#       5 from .val import RTDETRValidator
#
# File e:\My Projects\Number Plate detection\myvenv\lib\site-packages\ultralytics\models\rtdetr\model.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       2 """
#       3 RT-DETR model interface
#       4 """
# ----> 5 from ultralytics.engine.model import Model
#       6 from ultralytics.nn.tasks import RTDETRDetectionModel
#       8 from .predict import RTDETRPredictor
#
# File e:\My Projects\Number Plate detection\myvenv\lib\site-packages\ultralytics\engine\model.py:8
#       5 from pathlib import Path
#       6 from typing import Union
# ----> 8 from ultralytics.cfg import TASK2DATA, get_cfg, get_save_dir
#       9 from ultralytics.hub.utils import HUB_WEB_ROOT
#      10 from ultralytics.nn.tasks import attempt_load_one_weight, guess_model_task, nn, yaml_model_load
#
# File e:\My Projects\Number Plate detection\myvenv\lib\site-packages\ultralytics\cfg\__init__.py:10
#       7 from types import SimpleNamespace
#       8 from typing import Dict, List, Union
# ---> 10 from ultralytics.utils import (ASSETS, DEFAULT_CFG, DEFAULT_CFG_DICT, DEFAULT_CFG_PATH, LOGGER, RANK, SETTINGS,
#      11                                SETTINGS_YAML, IterableSimpleNamespace, __version__, checks, colorstr, deprecation_warn,
#      12                                yaml_load, yaml_print)
#      14 # Define valid tasks and modes
#      15 MODES = 'train', 'val', 'predict', 'export', 'track', 'benchmark'
#
# File e:\My Projects\Number Plate detection\myvenv\lib\site-packages\ultralytics\utils\__init__.py:19
#      16 from typing import Union
#      18 import cv2
# ---> 19 import matplotlib.pyplot as plt
#      20 import numpy as np
#      21 import torch
#
# File e:\My Projects\Number Plate detection\myvenv\lib\site-packages\matplotlib\pyplot.py:66
#      63 from matplotlib import _docstring
#      64 from matplotlib.backend_bases import (
#      65     FigureCanvasBase, FigureManagerBase, MouseButton)
# ---> 66 from matplotlib.figure import Figure, FigureBase, figaspect
#      67 from matplotlib.gridspec import GridSpec, SubplotSpec
#      68 from matplotlib import rcsetup, rcParamsDefault, rcParamsOrig
#
# File e:\My Projects\Number Plate detection\myvenv\lib\site-packages\matplotlib\figure.py:43
#      40 import numpy as np
#      42 import matplotlib as mpl
# ---> 43 from matplotlib import _blocking_input, backend_bases, _docstring, projections
#      44 from matplotlib.artist import (
#      45     Artist, allow_rasterization, _finalize_rasterization)
#      46 from matplotlib.backend_bases import (
#      47     DrawEvent, FigureCanvasBase, NonGuiException, MouseButton, _get_renderer)
#
# File e:\My Projects\Number Plate detection\myvenv\lib\site-packages\matplotlib\projections\__init__.py:58
#      56 from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#      57 from .polar import PolarAxes
# ---> 58 from mpl_toolkits.mplot3d import Axes3D
#      61 class ProjectionRegistry:
#      62     """A mapping of registered projection names to projection classes."""
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mpl_toolkits\mplot3d\__init__.py:1
# ----> 1 from .axes3d import Axes3D
#       3 __all__ = ['Axes3D']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:45
#      38 from . import proj3d
#      39 from . import axis3d
#      42 @_docstring.interpd
#      43 @_api.define_aliases({
#      44     "xlim": ["xlim3d"], "ylim": ["ylim3d"], "zlim": ["zlim3d"]})
# ---> 45 class Axes3D(Axes):
#      46     """
#      47     3D Axes object.
#      48     """
#      49     name = '3d'
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:718, in Axes3D()
#     716 get_zminorticklabels = _axis_method_wrapper("zaxis", "get_minorticklabels")
#     717 get_zticklabels = _axis_method_wrapper("zaxis", "get_ticklabels")
# --> 718 set_zticklabels = _axis_method_wrapper(
#     719     "zaxis", "_set_ticklabels",
#     720     doc_sub={"Axis.set_ticks": "Axes3D.set_zticks"})
#     722 zaxis_date = _axis_method_wrapper("zaxis", "axis_date")
#     723 if zaxis_date.__doc__:
#
# File e:\My Projects\Number Plate detection\myvenv\lib\site-packages\matplotlib\axes\_base.py:56, in _axis_method_wrapper.__init__(self, attr_name, method_name, doc_sub)
#      53 self.method_name = method_name
#      54 # Immediately put the docstring in ``self.__doc__`` so that docstring
#      55 # manipulations within the class body work as expected.
# ---> 56 doc = inspect.getdoc(getattr(maxis.Axis, method_name))
#      57 self._missing_subs = []
#      58 if doc:
#
# AttributeError: type object 'Axis' has no attribute '_set_ticklabels'

# %%
model = YOLO("best.pt")

# %%
img_path = "test1.jpg"

# %%
detections = model(img_path)[0]
# Out:
# image 1/1 e:\My Projects\Number Plate detection\test1.jpg: 640x480 1 Back Plate, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 480)

# %%
detections_ = []
for detection in detections.boxes.data.tolist():
    x1, y1, x2, y2, score, class_id = detection
    detections_.append([x1, y1, x2, y2, score])

# %%
fls = detections_[0]
fls
# Out:
# [123.73436737060547,
#  294.33111572265625,
#  333.6882629394531,
#  413.5721435546875,
#  0.517115592956543]

# %%
frame = cv2.imread(img_path)
crop = frame[int(fls[1]):int(fls[3]), int(fls[0]):int(fls[2])]

# %%
plt.imshow(crop)

# %% [markdown]
# ## **Text Detection**

# %%
import easyocr
reader = easyocr.Reader(['ch_sim','en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
result = reader.readtext(crop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\My Projects\Number Plate detection\plate_detection.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/My%20Projects/Number%20Plate%20detection/plate_detection.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> result = reader.readtext(crop)
#
# NameError: name 'crop' is not defined
