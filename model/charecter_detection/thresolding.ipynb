# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
img = cv2.imread("all_data\\charecters\\16\\image0.8393372971653272.jpg")
ret, thresh = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)

# %%
plt.imshow(thresh)

# %%
for i in os.listdir("all_data\\test data"):
    os.mkdir(os.path.join("thresold_charecters_test",i))
    for j in os.listdir(os.path.join("all_data\\test data", i)):
        path = f"all_data/test data/{i}/{j}" 
        img = cv2.imread(path)
        ret, thresh = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV) 
      
        # print(f"thresold_charecters/{i}/{j}")
        cv2.imwrite(f"thresold_charecters_test/{i}/{j}", thresh)
